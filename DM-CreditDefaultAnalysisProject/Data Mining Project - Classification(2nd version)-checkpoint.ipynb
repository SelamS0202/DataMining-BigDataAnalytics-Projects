# %% [markdown]
# # Data Understanding

# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns
from pandas.plotting import scatter_matrix

# %%
# Load the data

df = pd.read_csv('files/credit_default_train.csv')

# %%
#Changing all values of male and female to 1 and 0
df.loc[(df.sex == "male"), 'sex'] = 1
df.loc[(df.sex == "female"), 'sex'] = 0

# %%
#Changing all values of education to numeric values.
df.loc[(df.education == "others"), 'education'] = 0
df.loc[(df.education == "high school"), 'education'] = 1
df.loc[(df.education == "university"), 'education'] = 2
df.loc[(df.education == "graduate school"), 'education'] = 3

# %%
#Changing all values of status to numeric values.
df.loc[(df.status == "single"), 'status'] = 0
df.loc[(df.status == "married"), 'status'] = 1
df.loc[(df.status == "others"), 'status'] = 2

# %%
#Changing all values of credit_default to numeric values.
df.loc[(df.credit_default == "no"), 'credit_default'] = 0
df.loc[(df.credit_default == "yes"), 'credit_default'] = 1

# %%
#Filling missing values of sex with mode value of dataset which is 0 (female)
df['sex'] = df['sex'].fillna(df['sex'].mode()[0])

# %%
df.groupby(['education'])['sex'].agg([('modeSex', stats.mode)])
# Out:
#                  modeSex
# education
# 0            ([0], [26])
# 1          ([0], [1014])
# 2          ([0], [2908])
# 3          ([0], [2106])

# %%
#Filling missing values of education with mode value of dataset which is 2 (University)
df['education'] = df['education'].fillna(df['education'].mode()[0])

# %%
#calculating mode value of status based on education and sex
df.groupby(['education', 'sex'])['status'].agg([('modeStatus', stats.mode)])
# Out:
#                   modeStatus
# education sex
# 0         0      ([0], [11])
#           1       ([0], [3])
# 1         0     ([1], [518])
#           1     ([1], [282])
# 2         0    ([1], [1250])
#           1     ([0], [813])
# 3         0    ([0], [1148])
#           1     ([0], [679])

# %%
#Filling missing values of status based on table we calculated in previous step
fill = (df.education == 0) & (df.sex == 0) & (df.status.isnull())
df.loc[fill, 'status'] = 0
fill = (df.education == 0) & (df.sex == 1) & (df.status.isnull())
df.loc[fill, 'status'] = 0
fill = (df.education == 1) & (df.sex == 0) & (df.status.isnull())
df.loc[fill, 'status'] = 1
fill = (df.education == 1) & (df.sex == 1) & (df.status.isnull())
df.loc[fill, 'status'] = 1
fill = (df.education == 2) & (df.sex == 0) & (df.status.isnull())
df.loc[fill, 'status'] = 1
fill = (df.education == 2) & (df.sex == 1)& (df.status.isnull())
df.loc[fill, 'status'] = 0
fill = (df.education == 3) & (df.sex == 0)& (df.status.isnull())
df.loc[fill, 'status'] = 0
fill = (df.education == 3) & (df.sex == 1)& (df.status.isnull())
df.loc[fill, 'status'] = 0

# %%
#Creating a new column based on sex and status
df['sex_status'] = 0
df.loc[((df.sex == 1) & (df.status == 1)) , 'sex_status'] = 1 #married man
df.loc[((df.sex == 1) & (df.status == 0)) , 'sex_status'] = 2 #single man
df.loc[((df.sex == 1) & (df.status == 2)) , 'sex_status'] = 3 #divorced man
df.loc[((df.sex == 0) & (df.status == 1)) , 'sex_status'] = 4 #married woman
df.loc[((df.sex == 0) & (df.status == 0)) , 'sex_status'] = 5 #single woman
df.loc[((df.sex == 0) & (df.status == 2)) , 'sex_status'] = 6 #divorced woman

# %%
#Removing all rows with age value of -1 to calculate mean value in next step
df_temp = df
df_temp = df_temp.drop(df_temp[df_temp.age < 21].index)

# %%
#Generating mean value for age based on sex_status
df_temp.groupby('sex_status')['age'].mean()
# Out:
# sex_status
# 1    41.715616
# 2    33.133429
# 3    43.068966
# 4    37.962737
# 5    31.377128
# 6    41.300000
# Name: age, dtype: float64

# %%
#Changing all -1 values of age to mean values generated in previous step.
fill = (df.sex_status == 1) & (df.age < 21)
df.loc[fill, 'age'] = 41
fill = (df.sex_status == 2) & (df.age < 21)
df.loc[fill, 'age'] = 33
fill = (df.sex_status == 3) & (df.age < 21)
df.loc[fill, 'age'] = 43
fill = (df.sex_status == 4) & (df.age < 21)
df.loc[fill, 'age'] = 37
fill = (df.sex_status == 5) & (df.age < 21)
df.loc[fill, 'age'] = 31
fill = (df.sex_status == 6) & (df.age < 21)
df.loc[fill, 'age'] = 41

# %%
df['expense-may'] = df['ba-may']-(df['ba-apr']-df['pa-may'])
df['expense-jun'] = df['ba-jun']-(df['ba-may']-df['pa-jun'])
df['expense-jul'] = df['ba-jul']-(df['ba-jun']-df['pa-jul'])
df['expense-aug'] = df['ba-aug']-(df['ba-jul']-df['pa-aug'])
df['expense-sep'] = df['ba-sep']-(df['ba-aug']-df['pa-sep'])
df['avg-expense'] = (df['expense-may'] + df['expense-jun'] + df['expense-jul'] + df['expense-aug'] + df['expense-sep'])/5
# df[['limit', 'expense-may', 'expense-jun', 'expense-jul', 'expense-aug', 'expense-sep', 'credit_default']].head(5)

# %%
df['debt-apr'] = df['ba-apr']-df['pa-may']
df['debt-may'] = df['ba-may']-df['pa-jun'] + df['debt-apr']
df['debt-jun'] = df['ba-jun']-df['pa-jul'] + df['debt-may']
df['debt-jul'] = df['ba-jul']-df['pa-aug'] + df['debt-jun']
df['debt-aug'] = df['ba-aug']-df['pa-sep'] + df['debt-jul']

df['avg-debt'] = (df['debt-apr']+df['debt-may']+df['debt-jun']+df['debt-jul']+df['debt-aug'])/5
df['missed-payments'] = df[['ps-apr', 'ps-may', 'ps-jun', 'ps-jul', 'ps-aug', 'ps-sep']].max(axis=1)
df['avg-debt-to-limit-ratio'] = df['avg-debt']/df['limit']
df['avg-expense-to-limit-ratio'] = df['avg-expense']/df['limit']
# df[['limit','missed-payments','avg-debt','avg-debt-to-limit-ratio','credit_default']].sample(10)

# %%
df['avg-ba'] = (df['ba-apr']+df['ba-may']+df['ba-jun']+df['ba-jul']+df['ba-aug']+df['ba-sep'])/6
df['avg-pa'] = (df['pa-apr']+df['pa-may']+df['pa-jun']+df['pa-jul']+df['pa-aug']+df['pa-sep'])/6

# %% [markdown]
# # Classification

# %%
df['credit_default'].value_counts()
# Out:
# 0    7788
# 1    2212
# Name: credit_default, dtype: int64

# %%
# scatter_matrix(df[['limit', 'age','avg-debt','avg-expense']], figsize=(10, 10), c=df['credit_default'], s=50)
# plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
attributes = [col for col in df.columns if col != 'credit_default']
X = df[attributes].values
y = df['credit_default']

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, 
                                                    random_state=100, 
                                                    stratify=y)

# %%
clf = DecisionTreeClassifier(criterion='gini', max_depth=4, 
                             min_samples_split=2, min_samples_leaf=5)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# #### Features Importance

# %%
for col, imp in zip(attributes, clf.feature_importances_):
    print(col, imp)
# Out:
# limit 0.0
# sex 0.0
# education 0.007381410760189439
# status 0.0
# age 0.0
# ps-sep 0.6296276485986871
# ps-aug 0.051721701196031505
# ps-jul 0.019346694688990793
# ps-jun 0.0027230863224973647
# ps-may 0.0
# ps-apr 0.008391417651606703
# ba-sep 0.008588676860842262
# ba-aug 0.0
# ba-jul 0.0
# ba-jun 0.0
# ba-may 0.0
# ba-apr 0.0
# pa-sep 0.0
# pa-aug 0.0
# pa-jul 0.014338901262491993
# pa-jun 0.0
# pa-may 0.0
# pa-apr 0.0
# sex_status 0.0
# expense-may 0.0
# expense-jun 0.0
# expense-jul 0.0
# expense-aug 0.0
# expense-sep 0.02933121844958778
# avg-expense 0.04927045725741368
# debt-apr 0.0
# debt-may 0.0
# debt-jun 0.0
# debt-jul 0.0
# debt-aug 0.0
# avg-debt 0.0
# missed-payments 0.1792787869516614
# avg-debt-to-limit-ratio 0.0
# avg-expense-to-limit-ratio 0.0
# avg-ba 0.0
# avg-pa 0.0

# %% [markdown]
# #### Visualize the decision tree

# %%
import pydotplus
from sklearn import tree
from IPython.display import Image

# %%
import os
os.environ['PATH'] += os.pathsep + 'C:/Users/Pouria/Anaconda3/pkgs/graphviz-2.38-hfd603c8_2/Library/bin/graphviz'

# %%
dot_data = tree.export_graphviz(clf, out_file=None,  
                                feature_names=attributes, 
                                class_names=['Defaulted' if x == 1 else 'Not Defaulted' for x in clf.classes_],  
                                filled=True, rounded=True,  
                                special_characters=True,max_depth=3)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
y_train_pred = clf.predict(X_train)

# %%
print('Accuracy %s' % accuracy_score(y_train, y_train_pred))
print('F1-score %s' % f1_score(y_train, y_train_pred, average=None))
# Out:
# Accuracy 0.8254285714285714
# F1-score [0.89360961 0.51392204]

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.94      0.89      5452
#           1       0.67      0.42      0.51      1548
#
# avg / total       0.81      0.83      0.81      7000

# %%
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[5132,  320],
#        [ 902,  646]], dtype=int64)

# %%
y_test_pred = clf.predict(X_test)

# %%
print('Accuracy %s' % accuracy_score(y_test, y_test_pred))
print('F1-score %s' % f1_score(y_test, y_test_pred, average=None))
print(classification_report(y_test, y_test_pred))
confusion_matrix(y_test, y_test_pred)
# Out:
# Accuracy 0.819
# F1-score [0.88943189 0.50137741]
#              precision    recall  f1-score   support
#
#           0       0.85      0.93      0.89      2336
#           1       0.64      0.41      0.50       664
#
# avg / total       0.80      0.82      0.80      3000
# array([[2184,  152],
#        [ 391,  273]], dtype=int64)

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
lb = LabelBinarizer()
lb.fit(y_test)
lb.classes_.tolist()
# Out:
# [0, 1]

# %%
fpr, tpr, _ = roc_curve(y_test, y_test_pred)
roc_auc = auc(fpr, tpr)
print(roc_auc)

roc_auc = roc_auc_score(y_test, y_test_pred, average=None)
# Out:
# 0.673038042581284

# %%
plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % (roc_auc))
    
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=20)
plt.ylabel('True Positive Rate', fontsize=20) 
plt.tick_params(axis='both', which='major', labelsize=22)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.show()

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracy_cross_scores = cross_val_score(clf, X, y, cv=10)
print('Accuracy: %0.4f (+/- %0.2f)' % (accuracy_cross_scores.mean(), accuracy_cross_scores.std() * 2))

f1_cross_scores = cross_val_score(clf, X, y, cv=10, scoring='f1_macro')
print('F1-score: %0.4f (+/- %0.2f)' % (f1_cross_scores.mean(), f1_cross_scores.std() * 2))
# Out:
# Accuracy: 0.7959 (+/- 0.02)
# F1-score: 0.6579 (+/- 0.03)

# %%
accuracy_cross_scores
# Out:
# array([0.78821179, 0.81418581, 0.793     , 0.783     , 0.8       ,
#        0.79      , 0.807     , 0.81      , 0.78878879, 0.78478478])

# %% [markdown]
# ### Tuning the hyper-parameters

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
param_list = {'criterion': ['gini','entropy'],
              'max_depth': [None] + list(np.arange(2, 5)),
              'min_samples_split': [2, 5, 10, 20, 30, 50],
              'min_samples_leaf': [1, 5, 10, 20, 30, 50],
             }

grid_search = GridSearchCV(clf, param_grid=param_list)
grid_search.fit(X, y)
clf = grid_search.best_estimator_

# %%
report(grid_search.cv_results_, n_top=280)
# Out:
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 10
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 11
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 12
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 5}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 20
# Mean validation score: 0.820 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 59
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 74
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 85
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 94
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 94
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 94
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 94
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 94
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 94
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 94
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 5}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 101
# Mean validation score: 0.820 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 138
# Mean validation score: 0.819 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 138
# Mean validation score: 0.819 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 138
# Mean validation score: 0.819 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 138
# Mean validation score: 0.819 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 138
# Mean validation score: 0.819 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 138
# Mean validation score: 0.819 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 144
# Mean validation score: 0.819 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 145
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 146
# Mean validation score: 0.819 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 147
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 148
# Mean validation score: 0.819 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 159
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 160
# Mean validation score: 0.818 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 176
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 176
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
#
# Model with rank: 176
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 176
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 176
# Mean validation score: 0.818 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 181
# Mean validation score: 0.818 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 211
# Mean validation score: 0.817 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 223
# Mean validation score: 0.816 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 5}
#
# Model with rank: 223
# Mean validation score: 0.816 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 20}
#
# Model with rank: 223
# Mean validation score: 0.816 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 30}
#
# Model with rank: 226
# Mean validation score: 0.816 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 2}
#
# Model with rank: 226
# Mean validation score: 0.816 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 10}
#
# Model with rank: 226
# Mean validation score: 0.816 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 50, 'min_samples_split': 50}
#
# Model with rank: 229
# Mean validation score: 0.805 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 230
# Mean validation score: 0.804 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 231
# Mean validation score: 0.804 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 232
# Mean validation score: 0.804 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 233
# Mean validation score: 0.804 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 234
# Mean validation score: 0.804 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 235
# Mean validation score: 0.804 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 236
# Mean validation score: 0.803 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 5}
#
# Model with rank: 237
# Mean validation score: 0.802 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 10}
#
# Model with rank: 237
# Mean validation score: 0.802 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 30}
#
# Model with rank: 237
# Mean validation score: 0.802 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 50}
#
# Model with rank: 240
# Mean validation score: 0.802 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 20}
#
# Model with rank: 241
# Mean validation score: 0.802 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 30, 'min_samples_split': 2}
#
# Model with rank: 242
# Mean validation score: 0.800 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50}
#
# Model with rank: 243
# Mean validation score: 0.798 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 244
# Mean validation score: 0.797 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 245
# Mean validation score: 0.797 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 246
# Mean validation score: 0.797 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 247
# Mean validation score: 0.796 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 248
# Mean validation score: 0.795 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 5}
#
# Model with rank: 249
# Mean validation score: 0.795 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 20}
#
# Model with rank: 250
# Mean validation score: 0.795 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 2}
#
# Model with rank: 251
# Mean validation score: 0.795 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10}
#
# Model with rank: 252
# Mean validation score: 0.794 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 30}
#
# Model with rank: 253
# Mean validation score: 0.793 (std: 0.010)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 254
# Mean validation score: 0.789 (std: 0.007)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50}
#
# Model with rank: 255
# Mean validation score: 0.786 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 256
# Mean validation score: 0.784 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50}
#
# Model with rank: 257
# Mean validation score: 0.780 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 258
# Mean validation score: 0.775 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 259
# Mean validation score: 0.774 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#
# Model with rank: 260
# Mean validation score: 0.772 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 50}
#
# Model with rank: 261
# Mean validation score: 0.771 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 262
# Mean validation score: 0.771 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 263
# Mean validation score: 0.771 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 264
# Mean validation score: 0.770 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 265
# Mean validation score: 0.769 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 266
# Mean validation score: 0.768 (std: 0.008)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 267
# Mean validation score: 0.768 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 268
# Mean validation score: 0.767 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 5}
#
# Model with rank: 269
# Mean validation score: 0.766 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 270
# Mean validation score: 0.766 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#
# Model with rank: 271
# Mean validation score: 0.762 (std: 0.007)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 272
# Mean validation score: 0.757 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 273
# Mean validation score: 0.756 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 30}
#
# Model with rank: 274
# Mean validation score: 0.752 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 275
# Mean validation score: 0.750 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 276
# Mean validation score: 0.746 (std: 0.011)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 277
# Mean validation score: 0.746 (std: 0.008)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 278
# Mean validation score: 0.745 (std: 0.010)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 5}
#
# Model with rank: 279
# Mean validation score: 0.745 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 280
# Mean validation score: 0.745 (std: 0.009)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 2}

# %%
grid_search.best_estimator_.get_params()
# Out:
# {'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 50,
#  'min_samples_split': 30,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': False,
#  'random_state': None,
#  'splitter': 'best'}

# %%
param_list = {'max_depth': [None] + list(np.arange(2, 20)),
              'min_samples_split': [2, 5, 10, 20, 30, 50, 100],
              'min_samples_leaf': [1, 5, 10, 20, 30, 50, 100],
             }

random_search = RandomizedSearchCV(clf, param_distributions=param_list, 
                                   n_iter=100)
random_search.fit(X, y)
clf = random_search.best_estimator_

# %%
report(random_search.cv_results_, n_top=5)
# Out:
# Model with rank: 1
# Mean validation score: 0.821 (std: 0.003)
# Parameters: {'min_samples_split': 50, 'min_samples_leaf': 20, 'max_depth': 4}
#
# Model with rank: 2
# Mean validation score: 0.820 (std: 0.003)
# Parameters: {'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 4}
#
# Model with rank: 3
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'min_samples_split': 100, 'min_samples_leaf': 20, 'max_depth': 3}
#
# Model with rank: 3
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'min_samples_split': 5, 'min_samples_leaf': 5, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.820 (std: 0.004)
# Parameters: {'min_samples_split': 50, 'min_samples_leaf': 30, 'max_depth': 2}

# %%
random_search.best_estimator_.get_params()
# Out:
# {'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 20,
#  'min_samples_split': 50,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': False,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# # Testing

# %%
# Load the data

df_test = pd.read_csv('files/credit_default_test.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 24 columns):
# index        20000 non-null int64
# limit        20000 non-null int64
# sex          20000 non-null object
# education    19782 non-null object
# status       19970 non-null object
# age          20000 non-null int64
# ps-sep       20000 non-null int64
# ps-aug       20000 non-null int64
# ps-jul       20000 non-null int64
# ps-jun       20000 non-null int64
# ps-may       20000 non-null int64
# ps-apr       20000 non-null int64
# ba-sep       20000 non-null int64
# ba-aug       20000 non-null int64
# ba-jul       20000 non-null int64
# ba-jun       20000 non-null int64
# ba-may       20000 non-null int64
# ba-apr       20000 non-null int64
# pa-sep       20000 non-null int64
# pa-aug       20000 non-null int64
# pa-jul       20000 non-null int64
# pa-jun       20000 non-null int64
# pa-may       20000 non-null int64
# pa-apr       20000 non-null int64
# dtypes: int64(21), object(3)
# memory usage: 3.7+ MB

# %%
#Changing all values of male and female to 1 and 0
df_test.loc[(df_test.sex == "male"), 'sex'] = 1
df_test.loc[(df_test.sex == "female"), 'sex'] = 0

#Changing all values of education to numeric values.
df_test.loc[(df_test.education == "others"), 'education'] = 0
df_test.loc[(df_test.education == "high school"), 'education'] = 1
df_test.loc[(df_test.education == "university"), 'education'] = 2
df_test.loc[(df_test.education == "graduate school"), 'education'] = 3

#Changing all values of status to numeric values.
df_test.loc[(df_test.status == "single"), 'status'] = 0
df_test.loc[(df_test.status == "married"), 'status'] = 1
df_test.loc[(df_test.status == "others"), 'status'] = 2

# %%
#Filling missing values of education with mode value of dataset which is 2 (University)
df_test['education'] = df_test['education'].fillna(df_test['education'].mode()[0])

# %%
#calculating mode value of status based on education and sex
df_test.groupby(['education', 'sex'])['status'].agg([('modeStatus', stats.mode)])
# Out:
#                   modeStatus
# education sex
# 0         0      ([0], [32])
#           1      ([0], [18])
# 1         0    ([1], [1181])
#           1     ([1], [697])
# 2         0    ([1], [3067])
#           1    ([0], [2003])
# 3         0    ([0], [2762])
#           1    ([0], [1811])

# %%
#Filling missing values of status based on table we calculated in previous step
fill = (df_test.education == 0) & (df_test.sex == 0) & (df_test.status.isnull())
df_test.loc[fill, 'status'] = 0
fill = (df_test.education == 0) & (df_test.sex == 1) & (df_test.status.isnull())
df_test.loc[fill, 'status'] = 0
fill = (df_test.education == 1) & (df_test.sex == 0) & (df_test.status.isnull())
df_test.loc[fill, 'status'] = 1
fill = (df_test.education == 1) & (df_test.sex == 1) & (df_test.status.isnull())
df_test.loc[fill, 'status'] = 1
fill = (df_test.education == 2) & (df_test.sex == 0) & (df_test.status.isnull())
df_test.loc[fill, 'status'] = 1
fill = (df_test.education == 2) & (df_test.sex == 1)& (df_test.status.isnull())
df_test.loc[fill, 'status'] = 0
fill = (df_test.education == 3) & (df_test.sex == 0)& (df_test.status.isnull())
df_test.loc[fill, 'status'] = 0
fill = (df_test.education == 3) & (df_test.sex == 1)& (df_test.status.isnull())
df_test.loc[fill, 'status'] = 0

# %%
#Creating a new column based on sex and status
df_test['sex_status'] = 0
df_test.loc[((df_test.sex == 1) & (df_test.status == 1)) , 'sex_status'] = 1 #married man
df_test.loc[((df_test.sex == 1) & (df_test.status == 0)) , 'sex_status'] = 2 #single man
df_test.loc[((df_test.sex == 1) & (df_test.status == 2)) , 'sex_status'] = 3 #divorced man
df_test.loc[((df_test.sex == 0) & (df_test.status == 1)) , 'sex_status'] = 4 #married woman
df_test.loc[((df_test.sex == 0) & (df_test.status == 0)) , 'sex_status'] = 5 #single woman
df_test.loc[((df_test.sex == 0) & (df_test.status == 2)) , 'sex_status'] = 6 #divorced woman

# %%
df_test['expense-may'] = df_test['ba-may']-(df_test['ba-apr']-df_test['pa-may'])
df_test['expense-jun'] = df_test['ba-jun']-(df_test['ba-may']-df_test['pa-jun'])
df_test['expense-jul'] = df_test['ba-jul']-(df_test['ba-jun']-df_test['pa-jul'])
df_test['expense-aug'] = df_test['ba-aug']-(df_test['ba-jul']-df_test['pa-aug'])
df_test['expense-sep'] = df_test['ba-sep']-(df_test['ba-aug']-df_test['pa-sep'])
df_test['avg-expense'] = (df_test['expense-may'] + df_test['expense-jun'] + df_test['expense-jul'] +
                          df_test['expense-aug'] + df_test['expense-sep'])/5

# %%
df_test['debt-apr'] = df_test['ba-apr']-df_test['pa-may']
df_test['debt-may'] = df_test['ba-may']-df_test['pa-jun'] + df_test['debt-apr']
df_test['debt-jun'] = df_test['ba-jun']-df_test['pa-jul'] + df_test['debt-may']
df_test['debt-jul'] = df_test['ba-jul']-df_test['pa-aug'] + df_test['debt-jun']
df_test['debt-aug'] = df_test['ba-aug']-df_test['pa-sep'] + df_test['debt-jul']

df_test['avg-debt'] = (df_test['debt-apr']+df_test['debt-may']+df_test['debt-jun']+df_test['debt-jul']+df_test['debt-aug'])/5
df_test['missed-payments'] = df_test[['ps-apr', 'ps-may', 'ps-jun', 'ps-jul', 'ps-aug', 'ps-sep']].max(axis=1)
df_test['avg-debt-to-limit-ratio'] = df_test['avg-debt']/df_test['limit']
df_test['avg-expense-to-limit-ratio'] = df_test['avg-expense']/df_test['limit']

# %%
df_test['avg-ba'] = (df_test['ba-apr']+df_test['ba-may']+df_test['ba-jun']+
                     df_test['ba-jul']+df_test['ba-aug']+df_test['ba-sep'])/6
df_test['avg-pa'] = (df_test['pa-apr']+df_test['pa-may']+df_test['pa-jun']+
                     df_test['pa-jul']+df_test['pa-aug']+df_test['pa-sep'])/6

# %%
TEST_attributes = [col for col in df_test.columns if col != 'index']
TEST_X = df_test[TEST_attributes].values

TEST_pred = clf.predict(TEST_X)

# %%
def outputResult(TEST_pred):
    f = open("result.csv", "w")
    f.write("index,credit_default\n")
    for i in range(20000):
        value = ""
        if(TEST_pred[i] == 0):
            value = "no"
        else:
            value = "yes"
        f.write(str(i) + "," + str(value) + "\n")

# %%
outputResult(TEST_pred)

# %%
# Load the data

df_pred = pd.read_csv('files/result.csv')
df_pred.head()
# Out:
#    index credit_default
# 0      0             no
# 1      1             no
# 2      2            yes
# 3      3             no
# 4      4             no

# %%
df_pred.groupby('credit_default').count()
# Out:
#                 index
# credit_default
# no              17347
# yes              2653

# %%
df.groupby('credit_default')['credit_default'].count()
# Out:
# credit_default
# 0    7788
# 1    2212
# Name: credit_default, dtype: int64
